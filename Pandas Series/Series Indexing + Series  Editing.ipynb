# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Series Indexing --> Fetching the item

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
#1. integer indexing --> Positive indexing
print(x[0])
print(x[1])

#2. Negative indexing --> Series not work on negative indexing
# Out:
# 12
# 13
